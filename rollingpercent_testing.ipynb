# %%
from strategy.rollingpercent import RollingPercent
from datetime import datetime, timedelta
import pytz
import pandas as pd
from tqdm import tqdm

# %%
RollingPercent.required_params()
# Out:
# {'timeframe': 'daily',
#  'requirement': 5,
#  'days': 7,
#  'value': True,
#  'currency': 'crypto'}

# %%
strat = RollingPercent(datetime(2015,1,1),datetime(2021,1,1))
strat.subscribe()
sim = strat.create_sim()
# Out:
# rolling_percent_sim: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 11.56it/s]

# %%
sim[sim["date"] >= datetime(2020,1,1)]
# Out:
#            date     adjclose     delta ticker    rolling_7 timeframe  \
# 1932 2020-01-01  7200.174316  0.010896    BTC  7279.495257     daily
# 1933 2020-01-02  6985.470215  0.035593    BTC  7243.281459     daily
# 1934 2020-01-03  7344.884277 -0.012932    BTC  7251.109445     daily
# 1935 2020-01-04  7410.656738 -0.020141    BTC  7264.347517     daily
# 1936 2020-01-05  7411.317383 -0.020459    BTC  7262.728167     daily
# ...         ...          ...       ...    ...          ...       ...
# 2288 2021-11-11  4730.384277 -0.017534    ETH  4648.870536     daily
# 2289 2021-11-12  4667.115234  0.001625    ETH  4674.709403     daily
# 2290 2021-11-13  4651.460449  0.008907    ETH  4693.263602     daily
# 2291 2021-11-14  4626.358887  0.014430    ETH  4694.092773     daily
# 2292 2021-11-15  4692.025391 -0.003225    ETH  4676.941057     daily
#
#       requirement  days  value currency
# 1932            5     7   True   crypto
# 1933            5     7   True   crypto
# 1934            5     7   True   crypto
# 1935            5     7   True   crypto
# 1936            5     7   True   crypto
# ...           ...   ...    ...      ...
# 2288            5     7   True   crypto
# 2289            5     7   True   crypto
# 2290            5     7   True   crypto
# 2291            5     7   True   crypto
# 2292            5     7   True   crypto
#
# [1334 rows x 10 columns]
