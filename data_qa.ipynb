# %%
from database.market import Market
from database.sec import SEC
import pandas as pd
from tqdm import tqdm
from datetime import datetime, timedelta, timezone
pd.options.mode.chained_assignment = None

# %%
market = Market()
sec = SEC()

# %%
market.connect()
sp5 = market.retrieve("sp500")
prices = market.retrieve("prices")
market.disconnect()

# %%
prices["date"] = prices["date"] = pd.to_datetime(prices["date"])

# %%
analysis = []
for ticker in tqdm(sp5["Symbol"].unique()):
    try:
        ticker_data = prices[prices["ticker"]==ticker]
        ticker_data.sort_values("date",ascending=False)
        ticker_data["prev"] = ticker_data["date"].shift(-1)
        ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
        ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
        max_diff = ticker_data["diff_days"].max()
        strange_dates = ticker_data[ticker_data["diff_days"]> 5]
        for row in strange_dates.iterrows():
            sd = row[1]["date"]
            ro = row[1]["prev"]
            diff = row[1]["diff_days"]
            analysis.append({"ticker":ticker,
                             "diff":diff,
                             "occurence_date":sd,
                             "return_date":ro})
    except Exception as e:
        print(str(e))
# Out:
#   0%|                                                                                                                                           | 0/505 [00:00<?, ?it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   0%|▎                                                                                                                                  | 1/505 [00:00<02:54,  2.88it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   0%|▌                                                                                                                                  | 2/505 [00:00<02:52,  2.91it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   1%|▊                                                                                                                                  | 3/505 [00:01<02:46,  3.02it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   1%|█                                                                                                                                  | 4/505 [00:01<02:47,  2.99it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   1%|█▎                                                                                                                                 | 5/505 [00:01<02:47,  2.98it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   1%|█▌                                                                                                                                 | 6/505 [00:02<02:47,  2.97it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   1%|█▊                                                                                                                                 | 7/505 [00:02<02:47,  2.97it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   2%|██                                                                                                                                 | 8/505 [00:02<02:48,  2.96it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   2%|██▎                                                                                                                                | 9/505 [00:03<02:46,  2.97it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   2%|██▌                                                                                                                               | 10/505 [00:03<02:47,  2.96it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   2%|██▊                                                                                                                               | 11/505 [00:03<02:47,  2.95it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   2%|███                                                                                                                               | 12/505 [00:04<02:45,  2.98it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   3%|███▎                                                                                                                              | 13/505 [00:04<02:46,  2.95it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   3%|███▌                                                                                                                              | 14/505 [00:04<02:44,  2.98it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   3%|███▊                                                                                                                              | 15/505 [00:05<02:45,  2.97it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   3%|████                                                                                                                              | 16/505 [00:05<02:45,  2.96it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   3%|████▍                                                                                                                             | 17/505 [00:05<02:45,  2.95it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   4%|████▋                                                                                                                             | 18/505 [00:06<02:43,  2.98it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   4%|████▉                                                                                                                             | 19/505 [00:06<02:39,  3.04it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   4%|█████▏                                                                                                                            | 20/505 [00:06<02:41,  3.01it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   4%|█████▍                                                                                                                            | 21/505 [00:07<02:42,  2.98it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   4%|█████▋                                                                                                                            | 22/505 [00:07<02:40,  3.01it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   5%|█████▉                                                                                                                            | 23/505 [00:07<02:37,  3.06it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   5%|██████▏                                                                                                                           | 24/505 [00:08<02:39,  3.01it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   5%|██████▍                                                                                                                           | 25/505 [00:08<02:39,  3.01it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   5%|██████▋                                                                                                                           | 26/505 [00:08<02:36,  3.07it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   5%|██████▉                                                                                                                           | 27/505 [00:09<02:37,  3.03it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   6%|███████▏                                                                                                                          | 28/505 [00:09<02:37,  3.03it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   6%|███████▍                                                                                                                          | 29/505 [00:09<02:38,  3.00it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   6%|███████▋                                                                                                                          | 30/505 [00:10<02:39,  2.98it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   6%|███████▉                                                                                                                          | 31/505 [00:10<02:39,  2.97it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   6%|████████▏                                                                                                                         | 32/505 [00:10<02:39,  2.96it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#   7%|████████▍                                                                                                                         | 33/505 [00:11<02:38,  2.99it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#  97%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉    | 489/505 [02:43<00:05,  2.97it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏   | 490/505 [02:44<00:05,  2.95it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍   | 491/505 [02:44<00:04,  3.00it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋   | 492/505 [02:44<00:04,  3.05it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉   | 493/505 [02:45<00:03,  3.03it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏  | 494/505 [02:45<00:03,  3.01it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍  | 495/505 [02:45<00:03,  2.98it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋  | 496/505 [02:46<00:02,  3.06it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉  | 497/505 [02:46<00:02,  3.06it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 498/505 [02:46<00:02,  3.03it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍ | 499/505 [02:47<00:01,  3.02it/s]C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["prev"] = ticker_data["date"].shift(-1)
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff"] = ticker_data["prev"] - ticker_data["date"]
# C:\Users\ericj\AppData\Local\Temp/ipykernel_4756/3005869013.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data["diff_days"] = [x.days for x in ticker_data["diff"]]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 505/505 [02:48<00:00,  2.99it/s]

# %%
a = pd.DataFrame(analysis)

# %%
a[a["occurence_date"]==a["occurence_date"].max()]
# Out:
#     ticker  diff            occurence_date               return_date
# 264    OGN  19.0 2021-05-14 00:00:00+00:00 2021-06-02 00:00:00+00:00

# %%
sec.connect()
quarterlies = []
for row in tqdm(list(sp5.iterrows())):
    try:
        cik = row[1]["CIK"]
        ticker = row[1]["Symbol"]
        funds = sec.retrieve_filing_data(cik)
        funds["filed"] = [datetime.strptime(str(x),"%Y%m%d").replace(tzinfo=timezone.utc) if "-" not in str(x) else \
                         datetime.strptime(str(x).split(" ")[0],"%Y-%m-%d").replace(tzinfor=timezone.utc) for x in funds["filed"]]
        funds["quarter"] = [x.quarter for x in funds["filed"]]
        funds["year"] = [x.year for x in funds["filed"]]
        funds["ticker"] = ticker
        start = int(funds["year"].min())
        end = int(funds["year"].max())
        for year in range(start,end):
            for quarter in range(1,5):
                if year == 2021 and quarter == 4 or (year == 2009 and quarter < 3):
                    continue
                else:
                    filing = funds[(funds["year"]==year) & (funds["quarter"]==quarter)]
                    if filing.index.size < 1:
                        quarterlies.append({
                            "ticker":ticker,
                            "year":year,
                            "quarter":quarter
                        })
                    else:
                        continue
    except Exception as e:
        print(str(e))
sec.disconnect()
# Out:
#  38%|█████████████████████████████████████████████████▌                                                                               | 194/505 [00:56<01:31,  3.40it/s]
# 'filed'
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 505/505 [02:27<00:00,  3.42it/s]

# %%
qa = pd.DataFrame(quarterlies)

# %%
qa[(qa["year"]>2012) & (qa["ticker"]=="GOOGL")]
# Out:
#    ticker  year  quarter
# 64  GOOGL  2015        1
# 65  GOOGL  2015        2
# 66  GOOGL  2015        3
